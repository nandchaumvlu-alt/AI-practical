# %% [markdown]
# Pract7 part 4

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
#Load dataset 
iris=load_iris()
x=iris.data
y=iris.target
#Create classification model
model=KNeighborsClassifier()
#Apply 5-fold cross-validation
scores=cross_val_score(model,x,y,cv=5)
print("Accuracy scores for each fold:")
print(scores)
print("Average Accuracy:",round(scores.mean()*100,2),"%")
print("Nandini Chaudhary T006")
# Out:
# Accuracy scores for each fold:
# [0.96666667 1.         0.93333333 0.96666667 1.        ]
# Average Accuracy: 97.33 %
# Nandini Chaudhary T006

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsRegressor
# Load dataset
data = pd.read_csv("California_Housing.csv")
# Features and Target
X = data.drop("MedHouseVal", axis=1)   
y = data["MedHouseVal"]                
# Create Regression Model
model = KNeighborsRegressor()
# Apply 5-Fold Cross Validation
scores = cross_val_score(model, X, y, cv=5)
print("Accuracy Score for each fold:")
print(scores)
print("Average Accuracy Score:", round(scores.mean(), 4))
print("Nandini Chaudhary T006")
# Out:
# Accuracy Score for each fold:
# [ -5.88495857 -59.91906722  -0.17697979  -1.48992828 -66.10774044]
# Average Accuracy Score: -26.7157
# Nandini Chaudhary T006

# %% [markdown]
# pract 7 part 5

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
# Load dataset
iris = load_iris()
X = iris.data
y = iris.target
# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=1
)
# Create model
model = DecisionTreeClassifier()
# Train model
model.fit(X_train, y_train)
# Display accuracy
print("Training Accuracy:", model.score(X_train, y_train) * 100)
print("Testing Accuracy:", model.score(X_test, y_test) * 100)
# Prediction
prediction = model.predict([X_test[0]])
print("Predicted Class:", prediction[0])
print("Nandini Chaudhary T006")
# Out:
# Training Accuracy: 100.0
# Testing Accuracy: 95.55555555555556
# Predicted Class: 0
# Nandini Chaudhary T006

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
# Load dataset
data = pd.read_csv("California_Housing.csv")
# Features and Target
X = data.drop("MedHouseVal", axis=1)
y = data["MedHouseVal"]
# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=1
)
# Create model
model = DecisionTreeRegressor()
# Train model
model.fit(X_train, y_train)
# Display accuracy (R² Score)
print("Training Score:", model.score(X_train, y_train) * 100)
print("Testing Score:", model.score(X_test, y_test) * 100)
# Prediction
prediction = model.predict([X_test.iloc[0]])
print("Predicted House Value:", prediction[0])
print("Nandini Chaudhary T006")
# Out:
# Training Score: 100.0
# Testing Score: -21.973423961929804
# Predicted House Value: 4.526
# Nandini Chaudhary T006
# c:\Users\mvlui\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
